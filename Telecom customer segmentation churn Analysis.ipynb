# %% [markdown]
# # Telecom_Customer_Segmentation_Churn

# %% [markdown]
# # Problem Statement
# - The dataset contains customer information from a telecom company, including demographics, service details, billing information, and churn status.

# %%
import numpy as np  # numpy for mathematical calculations
import pandas as pd   # pandas for loading dataset and data manipulation
import matplotlib.pyplot as plt  # matplotlib use to visulization
import seaborn as sns  # seaborn use for advance visulization

# %% [markdown]
# **Load Dataset**

# %%
df=pd.read_csv("C:\\Users\\Abc\\Downloads\\Telecom_Customer_Segmentation_Churn_Dataset.csv")
df
# Out:
#        CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 0               1   56  Female      41            78.22        5706.78
# 1               2   69    Male      55           120.48         790.58
# 2               3   46  Female       7            90.26        3419.78
# 3               4   32    Male      18            74.50         806.20
# 4               5   60  Female      43            46.38        1568.84
# ...           ...  ...     ...     ...              ...            ...
# 14995       14996   21    Male      67            36.40        3270.73
# 14996       14997   53   Other      53           105.39         600.40
# 14997       14998   65  Female      35            72.36        2048.91
# 14998       14999   34   Other       4            57.73         424.75
# 14999       15000   64   Other      68            97.19          94.08
#
#         Contract Type Has Internet Service Has Online Security Service  \
# ...

# %% [markdown]
# **In Dataset 15000 rows and 13 column are present.**

# %%
df.head() # to get first rows in dataset
# Out:
#    CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 0           1   56  Female      41            78.22        5706.78
# 1           2   69    Male      55           120.48         790.58
# 2           3   46  Female       7            90.26        3419.78
# 3           4   32    Male      18            74.50         806.20
# 4           5   60  Female      43            46.38        1568.84
#
#     Contract Type Has Internet Service Has Online Security Service  \
# 0        Two year                   No                         Yes
# 1        One year                  DSL                         Yes
# 2        One year                   No                          No
# 3        Two year                  DSL                          No
# 4  Month-to-month          Fiber optic                          No
#
#   Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# 0                        Yes                               0      1  South
# ...

# %%
df.tail() # to get last rows in data set
# Out:
#        CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 14995       14996   21    Male      67            36.40        3270.73
# 14996       14997   53   Other      53           105.39         600.40
# 14997       14998   65  Female      35            72.36        2048.91
# 14998       14999   34   Other       4            57.73         424.75
# 14999       15000   64   Other      68            97.19          94.08
#
#         Contract Type Has Internet Service Has Online Security Service  \
# 14995        One year                   No                         Yes
# 14996        Two year          Fiber optic                         Yes
# 14997  Month-to-month                  DSL                         Yes
# 14998        Two year          Fiber optic                         Yes
# 14999  Month-to-month                  DSL                          No
#
#       Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# ...

# %%
df.describe() # summary of only numerical column
# Out:
#          CustomerID           Age        Tenure  Monthly Charges  \
# count  15000.000000  15000.000000  15000.000000     15000.000000
# mean    7500.500000     43.452667     35.996067        80.517022
# std     4330.271354     14.910732     20.509132        29.155010
# min        1.000000     18.000000      1.000000        30.000000
# 25%     3750.750000     31.000000     18.000000        55.417500
# 50%     7500.500000     43.000000     36.000000        80.495000
# 75%    11250.250000     56.000000     54.000000       105.800000
# max    15000.000000     69.000000     71.000000       130.980000
#
#        Total Charges  Number of Complaints Last Year         Churn
# count   15000.000000                    15000.000000  15000.000000
# mean     2898.212717                        4.469200      0.292867
# std      2042.690053                        2.882754      0.455093
# min        30.080000                        0.000000      0.000000
# ...

# %%
df.describe(include='all') # summary of both numerical and categorical columns
# Out:
#           CustomerID           Age  Gender        Tenure  Monthly Charges  \
# count   15000.000000  15000.000000   15000  15000.000000     15000.000000
# unique           NaN           NaN       3           NaN              NaN
# top              NaN           NaN  Female           NaN              NaN
# freq             NaN           NaN    5067           NaN              NaN
# mean     7500.500000     43.452667     NaN     35.996067        80.517022
# std      4330.271354     14.910732     NaN     20.509132        29.155010
# min         1.000000     18.000000     NaN      1.000000        30.000000
# 25%      3750.750000     31.000000     NaN     18.000000        55.417500
# 50%      7500.500000     43.000000     NaN     36.000000        80.495000
# 75%     11250.250000     56.000000     NaN     54.000000       105.800000
# max     15000.000000     69.000000     NaN     71.000000       130.980000
#
#         Total Charges Contract Type Has Internet Service  \
# ...

# %%
df.info() # information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CustomerID                      15000 non-null  int64
#  1   Age                             15000 non-null  int64
#  2   Gender                          15000 non-null  object
#  3   Tenure                          15000 non-null  int64
#  4   Monthly Charges                 15000 non-null  float64
#  5   Total Charges                   15000 non-null  float64
#  6   Contract Type                   15000 non-null  object
#  7   Has Internet Service            15000 non-null  object
#  8   Has Online Security Service     15000 non-null  object
#  9   Has Device Protection Plan      15000 non-null  object
#  10  Number of Complaints Last Year  15000 non-null  int64
#  11  Churn                           15000 non-null  int64
# ...

# %%
df.nunique() # to find unique value
# Out:
# CustomerID                        15000
# Age                                  52
# Gender                                3
# Tenure                               71
# Monthly Charges                    7759
# Total Charges                     14834
# Contract Type                         3
# Has Internet Service                  3
# Has Online Security Service           2
# Has Device Protection Plan            2
# Number of Complaints Last Year       10
# Churn                                 2
# Region                                4
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID                        0
# Age                               0
# Gender                            0
# Tenure                            0
# Monthly Charges                   0
# Total Charges                     0
# Contract Type                     0
# Has Internet Service              0
# Has Online Security Service       0
# Has Device Protection Plan        0
# Number of Complaints Last Year    0
# Churn                             0
# Region                            0
# dtype: int64

# %%
df.duplicated().sum() # to get duplicate value in data set
# Out:
# 0

# %% [markdown]
# **The data set have does not contain any duplicate value.**

# %%
df.shape  # fetching the rows and column
# Out:
# (15000, 13)

# %% [markdown]
# # EDA (Exploratary Data Analysis)

# %%
# histplot for CustomerID distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['CustomerID'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("CustomerID Distribution")
plt.xlabel("CustomerID")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Customer ID**
# - The graph is evenly distributed.
# - The line increase between 0-2000.

# %%
# histplot for age distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Age'],bins=20,kde=True,color='red')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Age**
# - The highest age in the dataset  is 69.
# - The age range with the highest number of cutomer is around 50 year old (928 customer).
# - The lowest customer count appears around 20-30 (552 at around age 25).

# %%
 #count for Gender distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Gender'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\3348701213.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Gender'],palette='coolwarm')

# %% [markdown]
# **Gender**
# - The graph shows  nearly balanced distribution
# - Female(5067 customer),Male(4946 customer), and other(4987 customer) are all close in count.
# - The count of Female customer is higher than Male and other gender.

# %%
# histplot for Tenure  distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Tenure'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Tenure  Distribution")
plt.xlabel("Tenure ")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Tenure**
# - The graph shows fairly even distribution with some fluctuations.
# - The highest number of customer(~885) is around the 20-30 month range.
# - There are fluctuations where some tenure bins drop to around 500-600

# %%
# histplot for Monthly Charges  distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Monthly Charges'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Monthly Charges Distribution")
plt.xlabel("Monthly Charges")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Monthly Charges**
# - The graph is fairly distributed.
# - The highest monthly charges is 796 in the graph.
# - customer counts remain relatively stable across most price ranges (most bins have 700-800 customers).

# %%
# histplot for Total Charges  distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Total Charges'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Total Charges Distribution")
plt.xlabel("Total Charges")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Total charges**
# - The distribution is right-skewed .
# - The highest concentration of customers falls between 0 and 3000 total charges,peaking at around 1434  in one of the bins.
# - The total charges $4000 number of customers gradually decreases.

# %%
#count for contract distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Contract Type'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Contract Distribution")
plt.xlabel("Contract")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\373152169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Contract Type'],palette='coolwarm')

# %% [markdown]
# **Contract Type**
# - The graph is fairly balanced distributed.
# - "One year" (5030)and "Two year" (5000) usually indicate higher customer than "Month-to-month" contract.

# %%
#count for Has Internet Service distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Has Internet Service'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Has Internet Service Distribution")
plt.xlabel("Has Internet Service")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\4016211998.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Has Internet Service'],palette='coolwarm')

# %% [markdown]
# **Has Internet Service**
# - The distribution is fairly balanced.
# - DSL (5040) has the highest count followed closely by "No internet" users,and "Fiber optic" users.

# %%
#count for Has Online Security Service distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Has Online Security Service'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Has Online Security Service Distribution")
plt.xlabel("Has Online Security Service")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\943902179.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Has Online Security Service'],palette='coolwarm')

# %% [markdown]
# **Has Online Security Service**
# - The graph is fairly distributed.
# - The count of "Yes" (7566) is higher than count of "No".

# %%
#count for Has Device protection Plan distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Has Device Protection Plan'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Has Device protection Plan  Distribution")
plt.xlabel("Has Device protection Plan")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\2539621810.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Has Device Protection Plan'],palette='coolwarm')

# %% [markdown]
# **Has Device Protection Plan**
# - The graph is fairly distributed.
# - There has  highest count of "No" (7590) whose no Device protection plan.

# %%
# histplot for Number of Complaints Last Year  distribution
plt.figure(figsize=(10,6))
ax=sns.histplot(df['Number of Complaints Last Year'],bins=20,kde=True,color='purple')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Number of Complaints Last Year Distribution")
plt.xlabel("Number of Complaints Last Year")
plt.ylabel("Distribution")
plt.show()

# %% [markdown]
# **Number of Complaints Last Year**
# - The graph is well distributed.
# - The highest count is 1554 complaints for specific category,while the lowest count is 1449 complaints.
# - The high number of repeated complaints shows unresolved issues.

# %%
#count for churn distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Churn'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("churn Distribution")
plt.xlabel("churn")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\1468607188.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Churn'],palette='coolwarm')

# %% [markdown]
# **churn**
# - 10607 customer have stayed with the company non churned.
# - 4393 customer have churn they left the service.

# %%
#count for region distribution
plt.figure(figsize=(12,6))
ax=sns.countplot(x=df['Region'],palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Region Distribution")
plt.xlabel("Region")
plt.ylabel("Distribution")
plt.show()
# Out:
# C:\Users\Abc\AppData\Local\Temp\ipykernel_4132\3844792335.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x=df['Region'],palette='coolwarm')

# %% [markdown]
# **Region**
# - The graph is Nearly equal distributed.
# - The count of "East" (3771).
# - Theere is no strong regional bias in the daatset.

# %%
x=['CustomerID','Age','Tenure','Monthly Charges','Total Charges','Number of Complaints Last Year','Churn']
def univariate_analysis(n):
    plt.figure(figsize=(20, 24))
    for i, col in enumerate(n, 1):
        plt.subplot(4,2,i)
        plt.title(f"Count of {col}")
        sns.boxplot(x=df[col])
    plt.show()

univariate_analysis(x)

# %% [markdown]
# - In Total charges there are highly outlier are present.

# %%
# Region vs Gender
plt.figure(figsize=(12,5))
ax=sns.countplot(data=df, x='Region',hue='Gender',palette='coolwarm')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Region vs Gender')
plt.xlabel('Region')
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# **Region vs Gender**
# - The East region has the highest number of Female customer(1301).
# - The North region has the highest number of Other customer(1325).
# - Across all four region the no of Female and Male customers is nearly equal.

# %% [markdown]
# # Non Graphical

# %%
df[df['Region']=='South'].head() # to get data where Region is south
# Out:
#    CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 0           1   56  Female      41            78.22        5706.78
# 2           3   46  Female       7            90.26        3419.78
# 3           4   32    Male      18            74.50         806.20
# 5           6   25    Male      40            50.43         423.90
# 9          10   40  Female      57            68.77         140.92
#
#     Contract Type Has Internet Service Has Online Security Service  \
# 0        Two year                   No                         Yes
# 2        One year                   No                          No
# 3        Two year                  DSL                          No
# 5        One year                   No                          No
# 9  Month-to-month                  DSL                         Yes
#
#   Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# 0                        Yes                               0      1  South
# ...

# %%
df[df['Region']=='North'].head() # to get data where Region is north
# Out:
#     CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 4            5   60  Female      43            46.38        1568.84
# 7            8   56    Male      14           104.97        4126.01
# 24          25   38    Male      31            65.19         119.82
# 28          29   61    Male      30            43.73        1949.41
# 29          30   42    Male      62            78.64         586.51
#
#      Contract Type Has Internet Service Has Online Security Service  \
# 4   Month-to-month          Fiber optic                          No
# 7         One year                   No                          No
# 24        Two year                   No                          No
# 28  Month-to-month                  DSL                         Yes
# 29        One year          Fiber optic                         Yes
#
#    Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# ...

# %%
df[df['Region']=='East'].head() # to get data where Region is east
# Out:
#     CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 1            2   69    Male      55           120.48         790.58
# 10          11   28  Female      46           105.72        2149.66
# 12          13   41  Female      24            88.32        1211.89
# 17          18   39  Female       6            65.15        3837.40
# 19          20   41    Male       7           110.60         712.16
#
#    Contract Type Has Internet Service Has Online Security Service  \
# 1       One year                  DSL                         Yes
# 10      Two year                  DSL                          No
# 12      One year          Fiber optic                          No
# 17      One year                   No                         Yes
# 19      Two year                  DSL                          No
#
#    Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# 1                          No                               9      0   East
# ...

# %%
df[df['Region']=='West'].head() # to get data where Region is west
# Out:
#     CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 6            7   38  Female      53            37.72         765.49
# 8            9   36    Male      21            37.78        2539.19
# 13          14   53    Male       5            87.69        4588.63
# 14          15   57    Male      42            39.11         151.68
# 16          17   20   Other      32            84.00        1380.68
#
#      Contract Type Has Internet Service Has Online Security Service  \
# 6   Month-to-month          Fiber optic                         Yes
# 8   Month-to-month          Fiber optic                          No
# 13        Two year                   No                          No
# 14        Two year          Fiber optic                         Yes
# 16  Month-to-month                  DSL                          No
#
#    Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# ...

# %%
df[df['Has Internet Service']=='DSL'].head() # to get data where internet service distribution is DSL
# Out:
#     CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 1            2   69    Male      55           120.48         790.58
# 3            4   32    Male      18            74.50         806.20
# 9           10   40  Female      57            68.77         140.92
# 10          11   28  Female      46           105.72        2149.66
# 11          12   28   Other      26           101.99        1215.69
#
#      Contract Type Has Internet Service Has Online Security Service  \
# 1         One year                  DSL                         Yes
# 3         Two year                  DSL                          No
# 9   Month-to-month                  DSL                         Yes
# 10        Two year                  DSL                          No
# 11  Month-to-month                  DSL                          No
#
#    Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# ...

# %%
df[df['Has Internet Service']=='Fiber optic'].head() # to get data where internet service distribution is fiber optic
# Out:
#     CustomerID  Age  Gender  Tenure  Monthly Charges  Total Charges  \
# 4            5   60  Female      43            46.38        1568.84
# 6            7   38  Female      53            37.72         765.49
# 8            9   36    Male      21            37.78        2539.19
# 12          13   41  Female      24            88.32        1211.89
# 14          15   57    Male      42            39.11         151.68
#
#      Contract Type Has Internet Service Has Online Security Service  \
# 4   Month-to-month          Fiber optic                          No
# 6   Month-to-month          Fiber optic                         Yes
# 8   Month-to-month          Fiber optic                          No
# 12        One year          Fiber optic                          No
# 14        Two year          Fiber optic                         Yes
#
#    Has Device Protection Plan  Number of Complaints Last Year  Churn Region
# ...

# %%
#using for loop  univariate
numerical_columns=['Age','Tenure','Monthly Charges','Total Charges','Number of Complaints Last Year','Churn']
categorical_columns=['Gender','Contract Type','Has Internet Service','Has Online Security Service','Has Device Protection Plan','Region']
def univariate_numerical(n):  # for numerical
  for i in n:
    plt.figure(figsize=(8,6))
    sns.histplot(x=i,data=df,color='blue',kde=True)
univariate_numerical(numerical_columns)

# %% [markdown]
# **Age**
# - The highest age in the dataset is 69.
# - The age range with the highest number of cutomer is around 50 year old (928 customer).
# - The lowest customer count appears around 20-30 (552 at around age 25).
#
# **Tenure**
# - The graph shows fairly even distribution with some fluctuations.
# - The highest number of customer(~885) is around the 20-30 month range.
# - There are fluctuations where some tenure bins drop to around 500-600
#
# **Monthly Charges**
# - The graph is fairly distributed.
# - The highest monthly charges is 796 in the graph.
# - customer counts remain relatively stable across most price ranges (most bins have 700-800 customers).
#
# **Total charges**
# - The distribution is right-skewed .
# - The highest concentration of customers falls between 0 and 3000 total charges,peaking at around 1434 in one of the bins.
# - The total charges $4000 number of customers gradually decreases.
#
# **Number of Complaints Last Year**
# - The graph is well distributed.
# - The highest count is 1554 complaints for specific category,while the lowest count is 1449 complaints.
# - The high number of repeated complaints shows unresolved issues.
#
# **churn**
# - The count of "0" is greater than "1"

# %%
# drop customerid column
df = df.drop(columns=["CustomerID"])
df.head()
# Out:
#    Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 0   56  Female      41            78.22        5706.78        Two year
# 1   69    Male      55           120.48         790.58        One year
# 2   46  Female       7            90.26        3419.78        One year
# 3   32    Male      18            74.50         806.20        Two year
# 4   60  Female      43            46.38        1568.84  Month-to-month
#
#   Has Internet Service Has Online Security Service Has Device Protection Plan  \
# 0                   No                         Yes                        Yes
# 1                  DSL                         Yes                         No
# 2                   No                          No                        Yes
# 3                  DSL                          No                         No
# 4          Fiber optic                          No                        Yes
#
#    Number of Complaints Last Year  Churn Region
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
num=['Gender','Contract Type','Has Internet Service','Region','Has Online Security Service','Has Device Protection Plan']
def bivariate_analysis(n):
    plt.figure(figsize=(14,10))
    for i,col in enumerate(n,1):
        plt.subplot(2,2,i)
        plt.title(f"count of {col}")
        sns.countplot(x=df[col],hue='Churn',data=df)
    plt.show()
bivariate_analysis(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 9
#       7         sns.countplot(x=df[col],hue='Churn',data=df)
#       8     plt.show()
# ----> 9 bivariate_analysis(num)
#
# Cell In[47], line 5, in bivariate_analysis(n)
#       3 plt.figure(figsize=(14,10))
#       4 for i,col in enumerate(n,1):
# ----> 5     plt.subplot(2,2,i)
#       6     plt.title(f"count of {col}")
#       7     sns.countplot(x=df[col],hue='Churn',data=df)
#
# File ~\Documents\ana\Lib\site-packages\matplotlib\pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
# ...

# %% [markdown]
# # Class Imbalence
# - Class imbalance happens when the number of instences in one class are higher than another data.

# %%
df_copy1=df.copy()
df_copy1
# Out:
#        Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 0       56  Female      41            78.22        5706.78        Two year
# 1       69    Male      55           120.48         790.58        One year
# 2       46  Female       7            90.26        3419.78        One year
# 3       32    Male      18            74.50         806.20        Two year
# 4       60  Female      43            46.38        1568.84  Month-to-month
# ...    ...     ...     ...              ...            ...             ...
# 14995   21    Male      67            36.40        3270.73        One year
# 14996   53   Other      53           105.39         600.40        Two year
# 14997   65  Female      35            72.36        2048.91  Month-to-month
# 14998   34   Other       4            57.73         424.75        Two year
# 14999   64   Other      68            97.19          94.08  Month-to-month
#
#       Has Internet Service Has Online Security Service  \
# ...

# %% [markdown]
# # Handling Class Imbalance
#
# 1.Over sampling
# - In oversampling method we use SMOTE(Synthetic minority oversampling Technique) is use.In this method we work on minority class(increase the minority class).create new similar example for minority group

# %%
from imblearn.over_sampling import RandomOverSampler

# Separate features (X) and target (y)
X = df_copy1.drop('Churn', axis=1)
y = df_copy1['Churn']

# Initialize RandomUnderSampler
ros = RandomOverSampler(random_state=42)

# Fit and apply the resampler to the data
X_resampled, y_resampled = ros.fit_resample(X, y)

# Convert the resampled data back to a DataFrame
new_df = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['Churn'])], axis=1)


new_df.head()
# Out:
#    Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 0   56  Female      41            78.22        5706.78        Two year
# 1   69    Male      55           120.48         790.58        One year
# 2   46  Female       7            90.26        3419.78        One year
# 3   32    Male      18            74.50         806.20        Two year
# 4   60  Female      43            46.38        1568.84  Month-to-month
#
#   Has Internet Service Has Online Security Service Has Device Protection Plan  \
# 0                   No                         Yes                        Yes
# 1                  DSL                         Yes                         No
# 2                   No                          No                        Yes
# 3                  DSL                          No                         No
# 4          Fiber optic                          No                        Yes
#
#    Number of Complaints Last Year Region  Churn
# ...

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Churn',data=new_df)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
print(new_df['Churn'].value_counts())
# Out:
# Churn
# 1    10607
# 0    10607
# Name: count, dtype: int64

# %% [markdown]
# # 2.Under sampling
# Undersampling is also known as DownSampling. it reduce/downsample number of example of majority class.

# %%
copy_2=df.copy()
copy_2
# Out:
#        Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 0       56  Female      41            78.22        5706.78        Two year
# 1       69    Male      55           120.48         790.58        One year
# 2       46  Female       7            90.26        3419.78        One year
# 3       32    Male      18            74.50         806.20        Two year
# 4       60  Female      43            46.38        1568.84  Month-to-month
# ...    ...     ...     ...              ...            ...             ...
# 14995   21    Male      67            36.40        3270.73        One year
# 14996   53   Other      53           105.39         600.40        Two year
# 14997   65  Female      35            72.36        2048.91  Month-to-month
# 14998   34   Other       4            57.73         424.75        Two year
# 14999   64   Other      68            97.19          94.08  Month-to-month
#
#       Has Internet Service Has Online Security Service  \
# ...

# %%
#  In under sampling   mejority class is decrease
from imblearn.under_sampling import RandomUnderSampler
# Separate features (X) and target (y)
X = copy_2.drop('Churn', axis=1)
y = copy_2['Churn']

# Initialize RandomUnderSampler
rus = RandomUnderSampler(random_state=42)

# Fit and apply the resampler to the data
X_resampled, y_resampled = rus.fit_resample(X, y)

new2_df = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['Churn'])], axis=1) # concate for we add two dataset

# print data 
new2_df.head()
# Out:
#        Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 436     33    Male      39            57.85        1806.95  Month-to-month
# 10259   24   Other       1            68.12        7265.98        One year
# 10707   56    Male      31            62.12        1103.01        Two year
# 1575    57  Female      22           129.92        6010.56  Month-to-month
# 12918   46    Male      23           127.60        2532.42  Month-to-month
#
#       Has Internet Service Has Online Security Service  \
# 436            Fiber optic                         Yes
# 10259                  DSL                          No
# 10707                  DSL                         Yes
# 1575           Fiber optic                          No
# 12918                   No                         Yes
#
#       Has Device Protection Plan  Number of Complaints Last Year Region  Churn
# 436                           No                               0  South      0
# ...

# %%
print(new2_df['Churn'].value_counts())
# Out:
# Churn
# 0    4393
# 1    4393
# Name: count, dtype: int64

# %% [markdown]
# # Handling Outlier
#
# #What is Outlier?
# - A data point that is significantly different from the rest of the data set.

# %%
outlier_copy=df.copy()
outlier_copy
# Out:
#        Age  Gender  Tenure  Monthly Charges  Total Charges   Contract Type  \
# 0       56  Female      41            78.22        5706.78        Two year
# 1       69    Male      55           120.48         790.58        One year
# 2       46  Female       7            90.26        3419.78        One year
# 3       32    Male      18            74.50         806.20        Two year
# 4       60  Female      43            46.38        1568.84  Month-to-month
# ...    ...     ...     ...              ...            ...             ...
# 14995   21    Male      67            36.40        3270.73        One year
# 14996   53   Other      53           105.39         600.40        Two year
# 14997   65  Female      35            72.36        2048.91  Month-to-month
# 14998   34   Other       4            57.73         424.75        Two year
# 14999   64   Other      68            97.19          94.08  Month-to-month
#
#       Has Internet Service Has Online Security Service  \
# ...

# %% [markdown]
# # IQR (Inter Quartile Range)

# %%
Q1=df['Total Charges'].quantile(0.25) # if data is 25% then it is Q1

# %%
Q3=df['Total Charges'].quantile(0.75) # if data is 75% then it is Q3

# %%
print(Q1,"\n",Q3)
# Out:
# 1254.25
#  4226.795

# %%
# IQR Finding
IQR=Q3-Q1
IQR
# Out:
# 2972.545

# %% [markdown]
# **Upper limit**

# %%
# finding upper limit
upper_limit=Q3+1.5*IQR  # formula for upper limit is Q3+1.5*IQR
print("Upper Limit ",upper_limit)
# Out:
# Upper Limit  8685.6125

# %% [markdown]
# **Lower limit**

# %%
# lower limit
lower_limit=Q1-1.5*IQR  # lower limit = Q1-1.5*IQR
print("Lower Limit",lower_limit)
# Out:
# Lower Limit -3204.5675

# %% [markdown]
# # Kurtosis
# - kurtosis is a statistical measure that describe the shape of a distribution to its peak.
# - It provide insights into the "tailedness" or extremity of data points.
#
# # Types of kurtosis
# - Mesokurtic (kurtosis = 3) : The distribution has a normal shape.
# - Leptokurtic (kurtosis > 3) : The distribution has heavy tails and a sharp peak.and it indicate more extreme outlier than a normal distribution.
# - platykurtic (kurtosis < 3) : The distribution has light tails and a flatter peak. and fewer extreme outliers compared to a normal distribution.
#
# # Skewness
# - Skewness measures the asymmetry of a distribution. It can indicate whether the data is symmetric, or skewed to the left or right
#
# # Types of skewness
# - Skewness = 0: Perfectly symmetric distribution (e.g., normal distribution).
# - Positive Skewness ( > 0): The tail on the right side is longer, and the bulk of data is concentrated on the left.
# - Negative Skewness ( < 0): The tail on the left side is longer, and the bulk of data is concentrated on the right.

# %%
from scipy.stats import skew,kurtosis
numerical_col=df.select_dtypes(include=['int64','float64']).columns
skewness=df[numerical_col].apply(skew).rename("skewness")
kurtosis_value=df[numerical_col].apply(kurtosis).rename("kurtosis")
distributionmatrix=pd.concat([skewness,kurtosis_value],axis=1)  
distributionmatrix
# Out:
#                                 skewness  kurtosis
# Age                             0.013529 -1.185103
# Tenure                          0.003092 -1.206663
# Monthly Charges                 0.009271 -1.193820
# Total Charges                   0.706986 -0.268290
# Number of Complaints Last Year  0.018517 -1.233190
# Churn                           0.910321 -1.171316

# %% [markdown]
# # Handling outlier
#
# # 1.log Transformation
# # What is log Transformation?
# - When data distribution is right skewed(positive value).
# - it reduce the impact of large values.
# - log transformation useful for regression model where extreme values dominated prediction.

# %%
df['Total Charges']=np.log1p(df['Total Charges'])

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x='Total Charges',data=outlier_copy)
plt.show()

# %%
from scipy.stats import skew,kurtosis
numerical_col=df.select_dtypes(include=['int64','float64']).columns
skewness=df[numerical_col].apply(skew).rename("skewness")
kurtosis_value=df[numerical_col].apply(kurtosis).rename("kurtosis")
distributionmatrix=pd.concat([skewness,kurtosis_value],axis=1)  
distributionmatrix
# Out:
#                                 skewness  kurtosis
# Age                             0.013529 -1.185103
# Tenure                          0.003092 -1.206663
# Monthly Charges                 0.009271 -1.193820
# Total Charges                  -1.171467  1.446997
# Number of Complaints Last Year  0.018517 -1.233190
# Churn                           0.910321 -1.171316

# %% [markdown]
# # Sqaue Root Transformation
# # What is Sqaue Root Transformation?
# - When data distribution is right skewed (less extreme value).
# - impact of large value but not as much as log transformation.

# %%
df['Total Charges']=np.sqrt(df['Total Charges'])

# %%
from scipy.stats import skew,kurtosis
numerical_col=df.select_dtypes(include=['int64','float64']).columns
skewness=df[numerical_col].apply(skew).rename("skewness")
kurtosis_value=df[numerical_col].apply(kurtosis).rename("kurtosis")
distributionmatrix=pd.concat([skewness,kurtosis_value],axis=1)  
distributionmatrix
# Out:
#                                 skewness  kurtosis
# Age                             0.013529 -1.185103
# Tenure                          0.003092 -1.206663
# Monthly Charges                 0.009271 -1.193820
# Total Charges                  -1.423902  2.437617
# Number of Complaints Last Year  0.018517 -1.233190
# Churn                           0.910321 -1.171316

# %%
#heatmap for numerical columns
Features=['Age','Tenure','Monthly Charges','Total Charges','Number of Complaints Last Year','Churn']
plt.figure(figsize=(10,4))
corr_matrix=df[Features].corr()
sns.heatmap(corr_matrix,annot=True,vmin=-1,vmax=1)
plt.title("correlation matrix numerical features")
plt.show()

# %% [markdown]
# # ANOVA
#
# # What is ANOVA?
# - ANOVA stands for Analysis of Variance.
# - ANOVA is a statistical test used to compare the means of two or more groups and determine if they are significantly different from each other.
# - we can apply only categorical data.
# - we can calculated by two methods:
#
# 1.F-statistics : The ratio of variance between group to variance within groups.
# 2.P_Value : Is the probability of obseving data no true differences between the group . if p_value < 0.05 i.e we reject the null hypothesis if p_value > 0.05 i.e fail to reject the null hypothesis.
#
# # Types of ANOVA
#
# 1.ONE-WAY:
# - There is only one independent variable and with more than two levels or groups.
#
# 2.TWO-WAY:
# - Two-way ANOVA is two different categorical independent variables on one dependent variable.

# %%
from scipy.stats import f_oneway # performs a one-way ANOVA test. for only one independent variable.
# define categorical column
categorical_col= ['Contract Type','Gender','Has Internet Service','Region','Has Online Security Service','Has Device Protection Plan']
for feature in categorical_col:
    groups = [df[df[feature] == category]['Churn'] for category in df[feature].unique()]
    f_stat, p_value = f_oneway(*groups) #unpacks the list of groups into separate arguments for the function.
    
    print(f"ANOVA results for {feature}:")
    print(f" F-statistic: {f_stat:.2f}")
    print(f" P-value: {p_value:.4f}\n")
# Out:
# ANOVA results for Contract Type:
#  F-statistic: 0.78
#  P-value: 0.4599
#
# ANOVA results for Gender:
#  F-statistic: 5.86
#  P-value: 0.0029
#
# ANOVA results for Has Internet Service:
#  F-statistic: 1.42
#  P-value: 0.2422
#
# ANOVA results for Region:
#  F-statistic: 0.24
#  P-value: 0.8697
#
# ANOVA results for Has Online Security Service:
#  F-statistic: 0.82
#  P-value: 0.3664
#
# ANOVA results for Has Device Protection Plan:
#  F-statistic: 1.68
#  P-value: 0.1947

# %% [markdown]
# **Contract Type**
# - F-statistic: 0.78
# - P-value: 0.4599 the p-value is greater than 0.05 so we reject null hypothesis.
#
# **Gender**
# - F-statistic: 5.86
# - P-value: 0.0029 the p-value is less than 0.05 so can fail to reject the null hypothesis.
#
# **Has Internet Service**
# - F-statistic: 1.42
# - P-value: 0.2422 the p-value is greater than 0.05 so we reject null hypothesis.
#
# **Region**
# - F-statistic: 0.24
# - P-value: 0.8697 the p-value is greater than 0.05 so we reject null hypothesis.
#
# **Has Online Security Service**
# - F-statistic: 0.82
# - P-value: 0.3664 the p-value is greater than 0.05 so we reject null hypothesis.
#
# **Has Device Protection Plan**
# - F-statistic: 1.68
# - P-value: 0.1947 the p-value is greater than 0.05 so we reject null hypothesis.

# %% [markdown]
# # Feature Selection

# %%
from sklearn.preprocessing import LabelEncoder
categorical_columns =['Contract Type','Gender','Has Internet Service','Region','Has Online Security Service','Has Device Protection Plan'] 

le= LabelEncoder()


for col in categorical_columns:
    df[col] = le.fit_transform(df[col])
corr_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap") 
plt.show()

# %%
# classification model
from sklearn.model_selection import train_test_split
x = df[['Age','Gender','Tenure','Monthly Charges','Total Charges','Contract Type','Has Internet Service','Has Online Security Service','Has Device Protection Plan','Number of Complaints Last Year','Region']]
y = df['Churn']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# Random forest classifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score
rf_model=RandomForestClassifier(random_state=42)
rf_model.fit(x_train,y_train)
y_pred=rf_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.7236666666666667
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84      2180
#            1       0.35      0.01      0.03       820
#
#     accuracy                           0.72      3000
#    macro avg       0.54      0.50      0.43      3000
# weighted avg       0.63      0.72      0.62      3000

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# XGBoost
from xgboost import XGBClassifier
xgb_classifier=XGBClassifier(n_estimators=100,random_state=42)
xgb_classifier.fit(x_train,y_train)
y_pred=xgb_classifier.predict(x_test)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.7236666666666667
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.90      0.80      2180
#            1       0.26      0.09      0.14       820
#
#     accuracy                           0.68      3000
#    macro avg       0.49      0.50      0.47      3000
# weighted avg       0.60      0.68      0.62      3000

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,accuracy_score
kn_model=KNeighborsClassifier()
kn_model.fit(x_train,y_train)
y_pred=kn_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.6476666666666666
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78      2180
#            1       0.24      0.14      0.18       820
#
#     accuracy                           0.65      3000
#    macro avg       0.48      0.49      0.48      3000
# weighted avg       0.59      0.65      0.61      3000

# %%
# SVC
from sklearn.svm import SVC
from sklearn.metrics import classification_report,accuracy_score
svc_model=SVC()
svc_model.fit(x_train,y_train)
y_pred=svc_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.7266666666666667
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84      2180
#            1       0.00      0.00      0.00       820
#
#     accuracy                           0.73      3000
#    macro avg       0.36      0.50      0.42      3000
# weighted avg       0.53      0.73      0.61      3000
# C:\Users\Abc\Documents\ana\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Abc\Documents\ana\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score
lg_model=LogisticRegression()
lg_model.fit(x_train,y_train)
y_pred=lg_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.7266666666666667
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84      2180
#            1       0.00      0.00      0.00       820
#
#     accuracy                           0.73      3000
#    macro avg       0.36      0.50      0.42      3000
# weighted avg       0.53      0.73      0.61      3000
# C:\Users\Abc\Documents\ana\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
# Gradient boosting
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report,accuracy_score
gb_model=GradientBoostingClassifier()
gb_model.fit(x_train,y_train)
y_pred=gb_model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
classification_rep=classification_report(y_test,y_pred)
print("classification report:\n",classification_rep)
# Out:
# Accuracy: 0.7256666666666667
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84      2180
#            1       0.36      0.00      0.01       820
#
#     accuracy                           0.73      3000
#    macro avg       0.55      0.50      0.43      3000
# weighted avg       0.63      0.73      0.61      3000

# %% [markdown]
# # Regression Model

# %%
#linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


model=LinearRegression()
model.fit(x_train, y_train)
y_pred_test=model.predict(x_test)#for evaluating test set
y_pred_train=model.predict(x_train)#for evaluating train set

#Evaluation Matrix
#now we are saving predictions
lr_metrics={'Test Mean Squared Error ':mean_squared_error(y_test,y_pred_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_pred_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_pred_test),
           'Test R Squared':r2_score(y_test,y_pred_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_pred_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_pred_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_pred_train),
           'Train R Squared':r2_score(y_train,y_pred_train)}
print(lr_metrics)
# Out:
# {'Test Mean Squared Error ': 0.19961088812011, 'Test Root Mean Squared Error': 0.44677834338753486, 'Test Mean Absolute Error': 0.4083833356131543, 'Test R Squared': -0.004977619758889107, 'Train Mean Squared Error': 0.20890814209615696, 'Train Root Mean Squared Error': 0.4570647023082804, 'Train Mean Absolute Error': 0.41781628419231404, 'Train R Squared': 0.0008933521111339493}

# %%
#multiple linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score


mlr=LinearRegression()
mlr.fit(x_train, y_train)
y_predmlr_test=mlr.predict(x_test)#for evaluating test set
y_predmlr_train=mlr.predict(x_train)#for evaluating train set

#Evaluation Matrix
#now we are saving predictions
mlr_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predmlr_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predmlr_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predmlr_test),
           'Test R Squared':r2_score(y_test,y_predmlr_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predmlr_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predmlr_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predmlr_train),
           'Train R Squared':r2_score(y_train,y_predmlr_train)}

print(mlr_metrics)
# Out:
# {'Test Mean Squared Error': 0.19961088812011, 'Test Root Mean Squared Error': 0.44677834338753486, 'Test Mean Absolute Error': 0.4083833356131543, 'Test R Squared': -0.004977619758889107, 'Train Mean Squared Error': 0.20890814209615696, 'Train Root Mean Squared Error': 0.4570647023082804, 'Train Mean Absolute Error': 0.41781628419231404, 'Train R Squared': 0.0008933521111339493}

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
y_predgb_test=gb.predict(x_test)
y_predgb_train=gb.predict(x_train)
gb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predgb_test),
           'Test R Squared':r2_score(y_test,y_predgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}

print(gb_metrics)
# Out:
# {'Test Mean Squared Error': 0.2003421883414887, 'Test Root Mean Squared Error': 0.4475960101938898, 'Test Mean Absolute Error': 0.40764288102978047, 'Test R Squared': -0.008659484825127794, 'Train Mean Squared Error': 0.19974453836505288, 'Train Root Mean Squared Error': 0.446927889446444, 'Train Mean Absolute Error': 0.4070695669359898, 'Train R Squared': 0.04471843865156777}

# %%
#XGBoost
from xgboost import XGBRegressor
xgb=XGBRegressor()
xgb.fit(x_train,y_train)
y_predxgb_test=xgb.predict(x_test)
y_predxgb_train=xgb.predict(x_train)
xgb_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predxgb_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predxgb_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predxgb_test),
           'Test R Squared':r2_score(y_test,y_predxgb_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predxgb_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predxgb_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predxgb_train),
           'Train R Squared':r2_score(y_train,y_predgb_train)}

print(xgb_metrics)
# Out:
# {'Test Mean Squared Error': 0.2312804519308616, 'Test Root Mean Squared Error': 0.48091626290952316, 'Test Mean Absolute Error': 0.4151595612341771, 'Test R Squared': -0.16442370414733887, 'Train Mean Squared Error': 0.09237151396770617, 'Train Root Mean Squared Error': 0.30392682337646043, 'Train Mean Absolute Error': 0.2539777630783998, 'Train R Squared': 0.04471843865156777}

# %%
#Random Forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_predrf_test=rf.predict(x_test)
y_predrf_train=rf.predict(x_train)
rf_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_predrf_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_predrf_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_predrf_test),
           'Test R Squared':r2_score(y_test,y_predrf_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_predrf_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_predrf_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_predrf_train),
           'Train R Squared':r2_score(y_train,y_predrf_train)}

print(rf_metrics)
# Out:
# {'Test Mean Squared Error': 0.2076046, 'Test Root Mean Squared Error': 0.45563647790755296, 'Test Mean Absolute Error': 0.4165866666666667, 'Test R Squared': -0.045223428059968596, 'Train Mean Squared Error': 0.03029471666666667, 'Train Root Mean Squared Error': 0.17405377521520948, 'Train Mean Absolute Error': 0.15674500000000002, 'Train R Squared': 0.8551150160358776}

# %%
#Decision Tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_preddt_test=dt.predict(x_test)
y_preddt_train=dt.predict(x_train)
dt_metrics={'Test Mean Squared Error':mean_squared_error(y_test,y_preddt_test),
           'Test Root Mean Squared Error':np.sqrt(mean_squared_error(y_test,y_preddt_test)),
           'Test Mean Absolute Error':mean_absolute_error(y_test,y_preddt_test),
           'Test R Squared':r2_score(y_test,y_preddt_test),
           'Train Mean Squared Error':mean_squared_error(y_train,y_preddt_train),
           'Train Root Mean Squared Error':np.sqrt(mean_squared_error(y_train,y_preddt_train)),
           'Train Mean Absolute Error':mean_absolute_error(y_train,y_preddt_train),
           'Train R Squared':r2_score(y_train,y_preddt_train)}

print(dt_metrics)
# Out:
# {'Test Mean Squared Error': 0.41233333333333333, 'Test Root Mean Squared Error': 0.6421318660005383, 'Test Mean Absolute Error': 0.41233333333333333, 'Test R Squared': -1.075967778026404, 'Train Mean Squared Error': 0.0, 'Train Root Mean Squared Error': 0.0, 'Train Mean Absolute Error': 0.0, 'Train R Squared': 1.0}
